# %% [markdown]
# # Experimenting with the Random Forest Model

# %% [markdown]
# ## Imports and Reading Data

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

data = pd.read_csv('data/iris.csv')
n = len(data)
# Used this to randomize the data
data = data.sample(frac=1).reset_index(drop=True)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 0             5.5          3.5           1.3          0.2      Iris-setosa
# 1             7.7          2.6           6.9          2.3   Iris-virginica
# 2             6.7          3.1           5.6          2.4   Iris-virginica
# 3             4.6          3.2           1.4          0.2      Iris-setosa
# 4             4.7          3.2           1.3          0.2      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 145           6.2          3.4           5.4          2.3   Iris-virginica
# 146           6.1          2.8           4.0          1.3  Iris-versicolor
# 147           5.4          3.0           4.5          1.5  Iris-versicolor
# 148           4.9          2.4           3.3          1.0  Iris-versicolor
# 149           4.6          3.6           1.0          0.2      Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Wrote this to convert the 
def parse_flower_type(Y):
    y = []
    for i in range(len(Y)):
        if (Y[i] == 'Iris-setosa'):
            y.append(1)
        elif (Y[i] == 'Iris-versicolor'):
            y.append(2)
        else:
            y.append(3)
    return y

# %%
training_factor = 0.6
training_size = round(training_factor * n)


Y_train = data.iloc[:training_size, 4].values
y_train = parse_flower_type(Y_train)

Y_test = data.iloc[training_size:, 4].values
y_test = parse_flower_type(Y_test)
x_train = data.iloc[:training_size, 0:4]
x_test = data.iloc[training_size:, 0:4]
# Out:
# RandomForestRegressor(max_depth=2)

# %%
reg = RandomForestRegressor(n_estimators=100, max_depth=2)

reg.fit(x_train, y_train)

pred = reg.predict(x_test)

mse = mean_squared_error(y_test, pred)
r2 = r2_score(y_test, pred)

print(f"Mean-Squared Error: {mse}")
print(f"R2 Score: {r2}")
# Out:
# Mean-Squared Error: 0.01272866554019775
# R2 Score: 0.9811814390370793
